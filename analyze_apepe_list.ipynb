# %%
# Load both CSV files
import pandas as pd

pd.set_option('display.max_rows', 200)

# Paths to the CSVs
# csv1_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_ll_v16.2-chroma-ISPDefaultInitialHype_original_HpatchesV4/aepe_list.csv"
# csv2_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_ll_v16.2-chroma-HumanTunedInitialHype_replicate-s21fe_lowlight_lr0.0005_schedulerPlateauTo0.00001_bs1_ga8_45000_HpatchesV4/aepe_list.csv"
# csv3_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_ll_FIXZEROGRADBUG_CFANORMALIZE_train_v16.2-chroma-HumanTunedInitialHype_lowlight_pooled480x640_allHomoRepeatedRaw_standardize_lr0.0005_gradac32_123000_HpatchesV4/aepe_list.csv"

# csv1_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_sl_v16.2-chroma-ISPDefaultInitialHype_original_HpatchesV4/aepe_list.csv"
# csv2_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_sl_v16.2-chroma-HumanTunedInitialHype_replicate-s21fe_sunlit_lr0.0005_schedulerPlateauTo0.00001_bs1_ga8_120000_HpatchesV4/aepe_list.csv"
# csv3_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_sl_FIXZEROGRADBUG_CFANORMALIZE_train_v16.2-chroma-HumanTunedInitialHype_sunlit_pooled480x640_allHomoRepeatedRaw_standardize_lr0.0005_gradac32_105000_HpatchesV4/aepe_list.csv"

# HPatchesV4.1
csv1_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_sl_v16.2-chroma-ISPDefaultInitialHype_original_HpatchesV4.1/aepe_list.csv"
csv2_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_sl_v16.2-chroma-HumanTunedInitialHype_replicate-s21fe_sunlit_lr0.0005_schedulerPlateauTo0.00001_bs1_ga8_120000_HpatchesV4.1/aepe_list.csv"
csv3_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_sl_FIXZEROGRADBUG_CFANORMALIZE_train_v16.2-chroma-HumanTunedInitialHype_sunlit_pooled480x640_allHomoRepeatedRaw_standardize_lr0.0005_gradac32_105000_HpatchesV4.1/aepe_list.csv"

# csv1_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_ll_v16.2-chroma-ISPDefaultInitialHype_original_HpatchesV4.1/aepe_list.csv"
# csv2_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_ll_v16.2-chroma-HumanTunedInitialHype_replicate-s21fe_sunlit_lr0.0005_schedulerPlateauTo0.00001_bs1_ga8_adjust_denoise3_120000_HpatchesV4.1/aepe_list.csv"
# csv3_path = "/home/boat/proxyISP/DGC-Net/proxydgc_eval/eval_ll_FIXZEROGRADBUG_CFANORMALIZE_train_v16.2-chroma-HumanTunedInitialHype_lowlight_pooled480x640_allHomoRepeatedRaw_standardize_lr0.0005_gradac32_123000_HpatchesV4.1/aepe_list.csv"

# Load CSVs
df1 = pd.read_csv(csv1_path)
df2 = pd.read_csv(csv2_path)
df3 = pd.read_csv(csv3_path)

# Merge all three CSVs on Sequence Name and Viewpoint
merged = df1.merge(df2, on=["Sequence Name", "Viewpoint"], suffixes=("_csv1", "_csv2"))
merged = merged.merge(df3, on=["Sequence Name", "Viewpoint"])
merged = merged.rename(columns={"EPE": "EPE_csv3"})

# Compute differences
merged["EPE_diff_1_2"] = merged["EPE_csv1"] - merged["EPE_csv2"]
merged["EPE_diff_1_3"] = merged["EPE_csv1"] - merged["EPE_csv3"]
merged["EPE_diff_2_3"] = merged["EPE_csv2"] - merged["EPE_csv3"]
# merged["EPE_trend"] = merged["EPE_diff_1_3"] - merged["EPE_diff_1_2"]

# Sort by any difference if desired
merged = merged.sort_values(by="EPE_diff_2_3")

# Display full merged table
merged
# Out:
#         Sequence Name  Viewpoint   EPE_csv1   EPE_csv2   EPE_csv3  \
# 139          sl_brick          6  55.079784  46.431469  55.031033
# 135       sl_pavement          6  28.813026  30.034542  35.897041
# 133          sl_moss2          6  27.162552  16.668289  20.249676
# 102       sl_pavement          4   8.623876   9.554448  12.051119
# 125          sl_stone          6  17.168131  27.291700  29.273502
# 70          sl_qrcode          5   2.891501   3.497555   5.256876
# 130    sl_chinesegirl          6  24.460636  25.127344  26.625916
# 118    sl_chinesegirl          5  15.710387  15.445075  16.617809
# 116        sl_mongkut          6  15.530083  13.902290  15.003355
# 89           sl_brick          3   5.789732   5.424002   6.470471
# 122           sl_cats          6  16.485430  16.999390  18.007196
# 110       sl_taladcat          6  12.152189  10.989954  11.896788
# 97       sl_taladlove          5   7.889569   8.218219   9.110276
# ...
